# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(re.search(pattern, string))

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to[0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to[^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to[^ ^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to[a-zA-Z0-9_].
#
#     \W    No alphanumeric presence[^a-zA-Z0-9_].
#
#     \     Is an escape character

# %% [markdown]
# Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall("([0-9]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall("([A-z]+)", "Hello I live on the 7th floor of 220 street of sims"))

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | **Refers to any character.**
# **^** | **Indicates that the beginning of the string must match <br/> (i.e. a string can only match if it starts in the same way, <br /> if it is preceded by spaces or a line break)**
# **$** | **Indicates that the end of the chain must match <br /> (the same remark as above applies, but at the end level).**
# **{n}**|**Indicates that the previous character must be repeated n times.**
# **{n, m}**|**Indicates that the previous character must be repeated between n and m times.**
#  *| **The previous character can be repeated none or several times. <br />For example, ab* may correspond to: a, ab, or a followed by any number of b.**
# **+**|**The previous character can be repeated once or several times. <br/>For example, to ab+ corresponds an a followed by any number of b.**
# **?**|**The previous character can be repeated zero or once.<br /> For example, to ab? correspond ab and a.**
# **\w** | **it corresponds to any alphabetical character, it is equivalent to [a-zA-Z].**
# **\W** | **it corresponds to everything that is not an alphabetical character.**
# **\d** | **it corresponds to any numeric character, i.e. it is equivalent to[0-9].**
# **\D** | **it corresponds to everything that is not a numeric character.**

# %% [markdown]
# ![alt text](http://www.codercaste.com/wp-content/uploads/2013/01/regex.gif)

# %% [markdown]
# ### Some useful resources
# http://www.rexegg.com/regex-quickstart.html
# http://www.dreambank.net/regex.html#examples
# https://pythex.org/ *(Pythex is a real-time regular expression editor for Python, a quick way to test your regular expressions.)*
# https://regex101.com/
# *(Regex101 is online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.)*

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
import re

number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")
# Out:
# Your number : 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-4a26eabf5c17> in <module>()
#       2
#       3 number = input("Your number : ")
# ----> 4 if re.match("^[0-9]+$", number):
#       5     print("The string entered is a number.")
#       6 else:
#
# C:\ProgramData\Anaconda2\lib\re.pyc in match(pattern, string, flags)
#     139     """Try to apply the pattern at the start of the string, returning
#     140     a match object, or None if no match was found."""
# --> 141     return _compile(pattern, flags).match(string)
#     142
#     143 def search(pattern, string, flags=0):
#
# TypeError: expected string or buffer

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")

# %% [markdown]
# ## Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
s = "sssgdds8sfsfs"
pattern = "[0-9]"
result = re.findall(pattern,s)
print(result)
# Out:
# ['8']

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
s = "sssgdds-8sfsfs"
result2 =re.findall('-?\d+\.?\d*',s)

print(result2)
# Out:
# ['-8']

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
s = "sssgdds-8s8fsfs"
result2 =re.findall('-?\d+\.?\d*',s)

print(result2)
# Out:
# ['-8', '8']

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."
numbers = re.findall('-?\d+\.?\d*',text)

print(numbers)
# Out:
# ['21', '3', '4', '003', '100.00']

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
text = "He had prudently disguised himself but was quickly captured by the police."
pattern =re.findall(r"ly\b", text)

print(pattern)
# Out:
# ['ly', 'ly']

# %% [markdown]
# **6. License plate number**
# A license plate consists of 2 capital letters, a dash ('-'), 3 digits, a dash ('-') and finally 2 capital letters. Write a script to check that an input string is a license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
plate = input("Enter your license plate number: ")

if re.match("^[A-Z]{2}-{1}\d{3}[A-Z]{2}", plate):
    print("The string entered is a license plate.")
else:
    print("The string entered is NOT a license plate.")
# Out:
# Enter your license plate number: 14mlk4
#   File "<string>", line 1
#     14mlk4
#          ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# **7 . Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is that of an IPv4 address.

# %%
ip = input("Enter your IP address :")


if re.match("(([0-2]*[0-5]*[0-5]+)[.]([0-2]*[0-5]*[0-5]+)[.]([0-2]*[0-5]*[0-5]+)[.]([0-2]*[0-5]*[0-5]+)$)", ip):
    print("The string entered is a IP address.")
else:
    print("The string entered is NOT a IP address.")
# Out:
# Enter your IP address :22.54.23
#   File "<string>", line 1
#     22.54.23
#            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
#
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
mail = False
while mail == False:
    
   mail = input("Enter your email :")
   if re.match("[A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+)", ip):
       print("The string entered is an email.")
   else:
    print("Please enter a valid email.")

# %% [markdown]
# **9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
password = input("Enter your password :")

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
password = input("Enter your password :")

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
import re
m = re.search(
    "Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))

# %%
# Another Example
import re
m = re.search(
    "^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    "audrey.boulevart@benextcomapgny.com",
    
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))

print(type(m))
# Out:
# audrey
# boulevart
# benextcomapgny
# com
# <type '_sre.SRE_Match'>

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
import re
list_mail = open("./data/mail.txt", "r")

print('+++++++')

lines = (list_mail.read())
emails = lines.split()

first_names = []
second_names = []
operators = []
zones = []

for email in emails:
    m = re.search(
    "^(?P<who>\w*)[.-_]?(?P<who2>\w*)@(?P<operator>\w+[.]?\w+?)[.](?P<zone>\w+$)", email)
    if m is not None:
        first_name = m.group("who")
        first_names.append(first_name)
        second_name = m.group("who2")
        second_names.append(second_name)
        operator = m.group("operator")
        operators.append(operator)
        zone = m.group("zone")
        zones.append(zone)
        
print((first_names))
print((zones))
print((operators))
# Out:
# +++++++
# ['aikin', 'moore', 'halknutson', 'alexnorquist', 'matthewlulloff', 'mark4451', 'monte', 'dan80', 'knutsondan', 'lepage', 'chapman_ben', 'upson1544', '552966959', 'soloman_ziegler', 'ortiz', 'ashwoon_hank', 'pettigrew', 'doranedward', 'mills_joe', 'valente_alex', 'yang', 'ike', 'hankshaffer', 'larrytrebil', 'davis_ike', 'davidsonhal', 'john8733', 'johnfletcher', 'cataldi_larry', 'rogerfietzer', 'edward4185', 'hancock_matthew', 'solberg_cast', 'georgepak', 'ike', 'tapia_quinn', '795419860', 'chambers_johnsen', 'jack', 'joe', 'reyesaaron', 'ben', 'pettigrewgeorge', 'miller', 'boyd_carl', 'yocum_mark', 'davidferro', 'george59', 'johnsen2201', 'thompson_adam', 'schutzlarry', 'quizoz', 'matthew8227', 'alex', 'georgemoody', 'lawicki589', 'doran7947', 'baueraaron', 'mark', 'waltermartin', 'kaskel', 'roberts_matthew', 'george', 'ferry', 'fred', 'jurgensonpeter', 'stevefietzer', 'sonderling_caswell', 'johnsen', 'mccormack', 'roberts', 'valente', 'ory_walter', 'tyirwin', 'paulferry', 'george', 'frank', 'ripka6596', 'wagner_schuster', 'mccormack', '851886792', 'zeaser_aaron', 'adam', 'tisler', 'severson_george', 'otto', 'illingsworth', 'danfletcher', 'alex685', 'hancock_valente', 'carl7884', 'paul9581', 'sawyer_chambers', 'johnsen', 'aaron', 'schiebel2392', 'mccormackedward', 'tapia1876', 'quizoz9628', 'rogerstahl', 'schutz_johnsen', 'carlupson', 'larry349', 'matthew', 'mcginnis', 'kalleg', 'nugent_jack', 'wagle_john', 'chapmannathan', 'hal536', '472510707', 'thomas', 'adamillingsworth', 'peterstahl', 'victortandy', 'fredturco', 'adam', 'ike3831', 'timfletcher', 'frank', '566486749', '675340599', 'davis_nathan', '253159777', 'edwardschutz', 'sagar_carl', '331837931', 'aaronbongard', 'ty9516', 'fred', 'schustersteve', 'moody_schiebel', 'soloman_ramachandran', 'victor630', 'yang_trebil', 'hoffman_zeller', 'ripka_thomas', 'vader', 'ottochambers', 'tylulloff', '263935905', 'carlvail', 'hanktisler', 'uddin1510', 'mccormack', 'vader', 'nelsonmark', 'zandt', 'uflan', 'dan6858', 'stahl', 'timirwin', 'davis9134', 'benuflan', 'davidziegler', 'carl1959', 'alexkeller', 'ostranderjoe', '469322116', 'monte7207', 'lawicki', 'fredtiernan', 'fietzer', 'benquinn', 'matthew8594', 'hal', 'sweeney', 'fletcher_monte', 'adamkalleg', 'woothomas', 'thomasdavidson', 'moore3490', 'walter', 'ventotla', 'dinkins', '950099319', 'roger', 'tim', 'sawyer', 'ben', 'carlmills', 'markboyd', 'johnyocum', '887934540', 'ortizjack', 'tiernan4456', 'roberts_myers', 'soloman8370', 'alex3716', 'tim', 'thompson85', 'reyes', 'resnick', 'dinkinsroger', 'mills9634', '821464747', 'valente_hydinger', 'schiebel1467', 'larryschiebel', 'adamostrander', 'jagtap', 'edward', 'matthewcataldi', 'resnick_moore', 'zeller', 'duffman', 'ottoortiz', 'david', 'delorenzo', 'miller_keller', 'illingsworth', 'nelson', 'rogers_john', 'fredwagner', 'tyresnick', 'hal', 'tiernan6950', 'mills', 'casal', 'zandt', 'stevevader', 'hankupson', '184536366', 'irwin_yang', 'napier', 'edward', 'rogers_lawicki', 'tapia_upson', 'uddin_yocum', 'bongardroger', 'victor', 'ty', 'paultiernan', 'roger836', 'pettigrew', 'steve', 'johnsen4863', '34658710', '284857146', '890280316', 'weinstein', 'alexschmitt', 'dan', 'steve', 'matthewfrick', '237336989', 'larry6016', 'otto5489', 'bongard_ty', '169102677', 'upson', 'hal', 'sonderling_mark', '430581778', 'walterkassing', 'victorceledon', 'kassing', 'duffman6005', 'frank', 'uddinotto', '703979481', 'paul', 'nugent', 'alex', 'aaronsweeney', 'knutson_celedon', 'tydoran', 'millerhal', 'adamnuttle', 'ashwoon8609', 'victormiller', 'mcginnis_reardon', 'ramachandran', 'monteshaffer', 'monte', 'pettigrew9750', 'yocum_dan', 'darnell8483', 'pettigrewlarry', 'yocum8146', 'ben5039', 'mcginnis', 'roger', 'adamtisler', 'matthew3420', 'john8770', 'hesch_zeller', 'christensen_ben', 'walter', 'ben8671', 'frankjagtap', 'peternuttle', 'victor8847', 'ferry', '690377034', 'lepageroger', 'john', '4709006', 'kaskel5284', 'cataldi_ingram', 'hanktiernan', 'ripka2474', 'cataldi_matthew', 'lewis_lulloff', 'm ...
# ['xyz', 'gov', 'xyz', 'com', 'me', 'gov', 'net', 'com', 'org', 'xyz', 'hu', 'hu', 'hu', 'tech', 'me', 'io', 'hu', 'net', 'xyz', 'net', 'hu', 'io', 'io', 'org', 'io', 'apple', 'com', 'me', 'com', 'apple', 'gov', 'gov', 'apple', 'me', 'com', 'io', 'tech', 'me', 'apple', 'tech', 'hu', 'com', 'me', 'xyz', 'me', 'com', 'com', 'gov', 'io', 'me', 'apple', 'tech', 'me', 'net', 'com', 'me', 'tech', 'gov', 'io', 'gov', 'tech', 'hu', 'hu', 'com', 'tech', 'tech', 'tech', 'tech', 'net', 'xyz', 'net', 'xyz', 'hu', 'tech', 'com', 'gov', 'apple', 'net', 'me', 'xyz', 'hu', 'apple', 'net', 'tech', 'org', 'hu', 'gov', 'net', 'com', 'net', 'apple', 'tech', 'xyz', 'gov', 'gov', 'xyz', 'com', 'tech', 'apple', 'apple', 'tech', 'me', 'me', 'tech', 'xyz', 'com', 'hu', 'gov', 'org', 'net', 'io', 'com', 'xyz', 'me', 'hu', 'hu', 'tech', 'apple', 'xyz', 'io', 'net', 'org', 'com', 'net', 'net', 'org', 'me', 'xyz', 'net', 'apple', 'tech', 'me', 'org', 'hu', 'me', 'me', 'tech', 'org', 'io', 'gov', 'tech', 'me', 'com', 'org', 'net', 'me', 'xyz', 'hu', 'gov', 'io', 'apple', 'me', 'tech', 'org', 'tech', 'apple', 'com', 'tech', 'tech', 'hu', 'io', 'net', 'org', 'com', 'xyz', 'xyz', 'apple', 'com', 'hu', 'tech', 'io', 'me', 'io', 'tech', 'gov', 'net', 'io', 'gov', 'org', 'tech', 'me', 'apple', 'apple', 'net', 'gov', 'xyz', 'tech', 'gov', 'me', 'me', 'hu', 'hu', 'hu', 'apple', 'xyz', 'gov', 'tech', 'io', 'net', 'gov', 'gov', 'com', 'net', 'tech', 'org', 'net', 'xyz', 'org', 'me', 'org', 'gov', 'tech', 'tech', 'org', 'io', 'xyz', 'tech', 'xyz', 'xyz', 'org', 'me', 'xyz', 'me', 'gov', 'org', 'xyz', 'apple', 'me', 'hu', 'net', 'gov', 'io', 'xyz', 'tech', 'io', 'me', 'apple', 'xyz', 'net', 'me', 'io', 'org', 'apple', 'me', 'com', 'io', 'org', 'tech', 'xyz', 'me', 'io', 'gov', 'me', 'com', 'tech', 'xyz', 'apple', 'hu', 'io', 'org', 'apple', 'apple', 'org', 'tech', 'apple', 'xyz', 'org', 'org', 'hu', 'tech', 'org', 'org', 'com', 'tech', 'gov', 'com', 'xyz', 'xyz', 'tech', 'me', 'tech', 'tech', 'xyz', 'xyz', 'tech', 'hu', 'apple', 'com', 'com', 'tech', 'com', 'gov', 'io', 'org', 'apple', 'gov', 'gov', 'tech', 'org', 'tech', 'io', 'tech', 'me', 'org', 'me', 'apple', 'hu', 'gov', 'org', 'apple', 'xyz', 'gov', 'apple', 'tech', 'tech', 'com', 'net', 'gov', 'io', 'gov', 'tech', 'gov', 'xyz', 'apple', 'apple', 'com', 'io', 'com', 'hu', 'io', 'apple', 'com', 'hu', 'io', 'net', 'xyz', 'tech', 'io', 'apple', 'hu', 'net', 'io', 'com', 'tech', 'hu', 'xyz', 'net', 'xyz', 'gov', 'me', 'apple', 'net', 'hu', 'hu', 'com', 'me', 'tech', 'xyz', 'me', 'me', 'gov', 'org', 'com', 'xyz', 'net', 'io', 'hu', 'org', 'net', 'com', 'tech', 'net', 'hu', 'tech', 'hu', 'hu', 'me', 'io', 'tech', 'net', 'apple', 'xyz', 'apple', 'net', 'gov', 'com', 'com', 'io', 'com', 'io', 'gov', 'com', 'com', 'net', 'org', 'xyz', 'tech', 'net', 'net', 'com', 'me', 'gov', 'com', 'me', 'apple', 'tech', 'me', 'me', 'net', 'tech', 'gov', 'com', 'com', 'org', 'org', 'io', 'com', 'hu', 'com', 'io', 'gov', 'apple', 'apple', 'org', 'me', 'com', 'tech', 'org', 'hu', 'xyz', 'apple', 'tech', 'hu', 'me', 'gov', 'me', 'io', 'net', 'apple', 'net', 'io', 'hu', 'com', 'hu', 'org', 'apple', 'tech', 'gov', 'org', 'com', 'xyz', 'me', 'xyz', 'hu', 'hu', 'tech', 'gov', 'apple', 'hu', 'tech', 'xyz', 'apple', 'io', 'net', 'org', 'xyz', 'com', 'org', 'gov', 'com', 'apple', 'io', 'gov', 'gov', 'gov', 'net', 'net', 'gov', 'tech', 'com', 'apple', 'net', 'com', 'hu', 'xyz', 'gov', 'tech', 'net', 'gov', 'com', 'net', 'xyz', 'tech', 'org', 'xyz', 'gov', 'net', 'com', 'xyz', 'me', 'org', 'tech', 'apple', 'gov', 'net', 'hu', 'gov', 'me', 'com', 'me', 'net', 'xyz', 'apple', 'hu', 'io', 'org', 'org', 'tech', 'me', 'apple', 'hu', 'apple', 'hu', 'tech', 'net', 'me', 'apple', 'xyz', 'io', 'com', 'xyz', 'tech', 'io', 'apple', 'io', 'org', 'apple', 'io', 'net', 'org', 'gov', 'apple', 'hu', 'com', 'com', 'tech', 'io', 'org', 'apple', 'hu', 'tech', 'io', 'xyz', 'org', 'io', 'net', 'gov', 'net', 'tech', 'net', 'xyz', 'me', 'gov', 'org', 'tech', 'io', 'tech', ...
# ['odul', 'imail', 'email', 'proton', 'mail.adlp', 'mail.bocode', 'belgaximus', 'mail.adlp', 'belgaximus', 'gaagle', 'napster', 'youhoo', 'belgaximus', 'email', 'napster', 'imail', 'proton', 'napster', 'imail', 'mail.adlp', 'email', 'ecoin', 'mail.bocode', 'email', 'odul', 'hotmoille', 'youhoo', 'youhoo', 'napster', 'imail', 'gaagle', 'belgaximus', 'gaagle', 'gaagle', 'ecoin', 'gaagle', 'imail', 'mail.bocode', 'gaagle', 'ecoin', 'mail.adlp', 'ecoin', 'odul', 'mail.bocode', 'napster', 'youhoo', 'mail.bocode', 'ecoin', 'imail', 'mail.bocode', 'email', 'napster', 'hotmoille', 'mail.bocode', 'hotmoille', 'hotmoille', 'gaagle', 'mail.adlp', 'email', 'ecoin', 'mail.bocode', 'mail.bocode', 'hotmoille', 'gaagle', 'odul', 'proton', 'ecoin', 'napster', 'odul', 'napster', 'proton', 'gaagle', 'proton', 'proton', 'hotmoille', 'youhoo', 'mail.adlp', 'mail.bocode', 'mail.adlp', 'imail', 'youhoo', 'belgaximus', 'proton', 'hotmoille', 'proton', 'proton', 'belgaximus', 'mail.adlp', 'hotmoille', 'hotmoille', 'mail.adlp', 'email', 'belgaximus', 'email', 'imail', 'hotmoille', 'proton', 'imail', 'belgaximus', 'odul', 'ecoin', 'napster', 'odul', 'youhoo', 'imail', 'mail.adlp', 'gaagle', 'napster', 'youhoo', 'napster', 'odul', 'hotmoille', 'youhoo', 'gaagle', 'youhoo', 'mail.bocode', 'email', 'proton', 'imail', 'gaagle', 'email', 'proton', 'ecoin', 'gaagle', 'hotmoille', 'hotmoille', 'napster', 'odul', 'belgaximus', 'mail.adlp', 'proton', 'hotmoille', 'gaagle', 'hotmoille', 'imail', 'imail', 'email', 'belgaximus', 'imail', 'email', 'youhoo', 'napster', 'ecoin', 'email', 'proton', 'proton', 'imail', 'belgaximus', 'mail.adlp', 'mail.adlp', 'odul', 'hotmoille', 'imail', 'mail.adlp', 'imail', 'youhoo', 'gaagle', 'mail.bocode', 'hotmoille', 'gaagle', 'mail.adlp', 'email', 'gaagle', 'proton', 'mail.adlp', 'email', 'gaagle', 'email', 'mail.bocode', 'napster', 'mail.bocode', 'mail.adlp', 'napster', 'mail.adlp', 'proton', 'imail', 'gaagle', 'hotmoille', 'belgaximus', 'napster', 'ecoin', 'belgaximus', 'mail.adlp', 'email', 'gaagle', 'mail.adlp', 'email', 'odul', 'ecoin', 'proton', 'proton', 'email', 'mail.bocode', 'youhoo', 'odul', 'odul', 'hotmoille', 'proton', 'ecoin', 'mail.adlp', 'proton', 'imail', 'youhoo', 'mail.adlp', 'email', 'email', 'youhoo', 'mail.bocode', 'ecoin', 'email', 'youhoo', 'odul', 'gaagle', 'mail.adlp', 'imail', 'napster', 'belgaximus', 'belgaximus', 'proton', 'gaagle', 'mail.bocode', 'odul', 'mail.adlp', 'gaagle', 'email', 'youhoo', 'gaagle', 'ecoin', 'gaagle', 'napster', 'youhoo', 'napster', 'youhoo', 'gaagle', 'email', 'mail.bocode', 'gaagle', 'mail.bocode', 'mail.adlp', 'ecoin', 'imail', 'odul', 'ecoin', 'hotmoille', 'hotmoille', 'email', 'youhoo', 'gaagle', 'ecoin', 'gaagle', 'gaagle', 'hotmoille', 'belgaximus', 'hotmoille', 'napster', 'ecoin', 'hotmoille', 'youhoo', 'belgaximus', 'youhoo', 'ecoin', 'ecoin', 'proton', 'odul', 'ecoin', 'hotmoille', 'belgaximus', 'hotmoille', 'youhoo', 'youhoo', 'mail.bocode', 'youhoo', 'proton', 'proton', 'proton', 'proton', 'napster', 'email', 'imail', 'mail.bocode', 'hotmoille', 'gaagle', 'email', 'gaagle', 'hotmoille', 'napster', 'email', 'proton', 'email', 'proton', 'napster', 'napster', 'ecoin', 'imail', 'gaagle', 'proton', 'imail', 'napster', 'belgaximus', 'mail.bocode', 'youhoo', 'hotmoille', 'odul', 'mail.adlp', 'mail.bocode', 'mail.adlp', 'odul', 'belgaximus', 'ecoin', 'email', 'odul', 'proton', 'mail.adlp', 'youhoo', 'imail', 'imail', 'proton', 'napster', 'imail', 'mail.adlp', 'mail.adlp', 'hotmoille', 'mail.bocode', 'proton', 'proton', 'napster', 'odul', 'hotmoille', 'youhoo', 'napster', 'belgaximus', 'hotmoille', 'gaagle', 'email', 'napster', 'youhoo', 'mail.bocode', 'imail', 'imail', 'gaagle', 'proton', 'belgaximus', 'gaagle', 'odul', 'napster', 'imail', 'imail', 'mail.adlp', 'belgaximus', 'proton', 'youhoo', 'email', 'mail.bocode', 'ecoin', 'imail', 'gaagle', 'imail', 'mail.bocode', 'imail', 'mail.bocode', 'mail.adlp', 'email', 'belgaximus', 'napster', 'gaagle', 'odul', 'email', 'mail.boc ...

# %% [markdown]
# **12. Another way of doing things.**

# %%
mail = "audrey.boulevart@benextcomapgny.com"
splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

firstName, name, ope, zone
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-d3a5c250f91b> in <module>()
#       1 mail = "audrey.boulevart@benextcomapgny.com"
# ----> 2 splitMail = mail.replace(".", " ").split("@").copy()
#       3
#       4 firstName = []
#       5 name = []
#
# AttributeError: 'list' object has no attribute 'copy'

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?
